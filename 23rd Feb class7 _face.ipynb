# %%
# !pip install pillow  
# !pip install requests
# Out:
# Requirement already satisfied: pillow in c:\users\82108\anaconda3\lib\site-packages (8.0.1)
# Requirement already satisfied: requests in c:\users\82108\anaconda3\lib\site-packages (2.24.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\82108\anaconda3\lib\site-packages (from requests) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\82108\anaconda3\lib\site-packages (from requests) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\82108\anaconda3\lib\site-packages (from requests) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\82108\anaconda3\lib\site-packages (from requests) (2.10)

# %%
import matplotlib.pyplot as plt   #그림관련
import matplotlib.image as mpimg  #사진관련

# %matplotlib inline

# %%
img = mpimg.imread('face1.jfif')

plt.figure(figsize = (10,8))
plt.imshow(img)
plt.show()

# %%
import requests  # 인터넷 연결

client_id = "JtzyEv6hdzG2mhfewvFn"
client_secret = "b7VOpgnzec"

url = "https://openapi.naver.com/v1/vision/celebrity"
files = {'image':open('face1.jfif','rb')}
headers = {'X-Naver-Client-Id':client_id, 'X-Naver-Client-Secret': client_secret}

response = requests.post(url, files = files, headers = headers)

# %%
#json을 다루는 모듈

import json
parsed = json.loads(response.text)
print(json.dumps(parsed, indent = 4, sort_keys=False, ensure_ascii=False))

#사진 한장의 최대 크기는 2메가로 제한 (네이버에서)
# Out:
# {
#     "info": {
#         "size": {
#             "width": 293,
#             "height": 172
#         },
#         "faceCount": 1
#     },
#     "faces": [
#         {
#             "celebrity": {
#                 "value": "김수현",
#                 "confidence": 0.287687
#             }
#         }
#     ]
# }

# %%
#얼굴 인식, 나이 예측, 감정 상태 등등 분석

import requests  # 인터넷 연결

client_id = "JtzyEv6hdzG2mhfewvFn"
client_secret = "b7VOpgnzec"

url = "https://openapi.naver.com/v1/vision/face"
files = {'image':open('face1.jfif','rb')}
headers = {'X-Naver-Client-Id':client_id, 'X-Naver-Client-Secret': client_secret}

response = requests.post(url, files = files, headers = headers)

# %%
import json
parsed = json.loads(response.text)
print(json.dumps(parsed, indent = 4, sort_keys=False, ensure_ascii=False))
# Out:
# {
#     "info": {
#         "size": {
#             "width": 293,
#             "height": 172
#         },
#         "faceCount": 1
#     },
#     "faces": [
#         {
#             "roi": {
#                 "x": 116,
#                 "y": 41,
#                 "width": 47,
#                 "height": 47
#             },
#             "landmark": {
#                 "leftEye": {
#                     "x": 128,
#                     "y": 53
#                 },
#                 "rightEye": {
#                     "x": 151,
#                     "y": 54
#                 },
#                 "nose": {
#                     "x": 138,
#                     "y": 67
#                 },
#                 "leftMouth": {
#                     "x": 128,
#                     "y": 78
#                 },
#                 "rightMouth": {
#                     "x": 147,
#                     "y": 80
#                 }
#             },
#             "gender": {
#                 "value": "male",
#                 "confidence": 0.999987
#             },
#             "age": {
#                 "value": "28~32",
#                 "confidence": 0.863172
#             },
#             "emotion": {
#                 "value": "neutral",
#                 "confidence": 1.0
#             },
#             "pose": {
#                 "value": "frontal_face",
#                 "confidence": 0.997373
#             }
#         }
#     ]
# }

# %%
#### 기본 문법 학습 #########

# %%
#dict 형과 json에 대해..

dict = {'Naver':'pinkwink','Age':'None','Class':['beginner','blog']}
dict
# Out:
# {'Naver': 'pinkwink', 'Age': 'None', 'Class': ['beginner', 'blog']}

# %%
dict.keys()
# Out:
# dict_keys(['Naver', 'Age', 'Class'])

# %%
dict.values()
# Out:
# dict_values(['pinkwink', 'None', ['beginner', 'blog']])

# %%
dict['Class']
# Out:
# ['beginner', 'blog']

# %%
dict.get('Naver')
# Out:
# 'pinkwink'

# %%
dict.get('Age','nothing')
# Out:
# 'None'

# %%
dict.get('Room','nothing')
# Out:
# 'nothing'

# %%
###### jason (Java Script Object Notation)#####

# %%
customer = {
    'id':'0001',
    'name':'홍길동',
    'history':[
        {'date':'2019-03-01','log':True},
        {'date':'2019-03-02','log':False},
    ]
}

# %%
import json
json_test = json.dumps(customer, indent = 4, ensure_ascii = False)
print(json_test)
# Out:
# {
#     "id": "0001",
#     "name": "홍길동",
#     "history": [
#         {
#             "date": "2019-03-01",
#             "log": true
#         },
#         {
#             "date": "2019-03-02",
#             "log": false
#         }
#     ]
# }

# %%
#### 사진 위에 정보 표시하기 #########

# %%
img = mpimg.imread('face1.jfif')

plt.figure(figsize=(10,8))
plt.imshow(img)
plt.show()

# %%
# 얼굴 인식, 나이 예측, 감정 상태 등등 분석

import requests  # 인터넷 연결

client_id = "JtzyEv6hdzG2mhfewvFn"
client_secret = "b7VOpgnzec"

url = "https://openapi.naver.com/v1/vision/face"
files = {'image':open('face1.jfif','rb')}
headers = {'X-Naver-Client-Id':client_id, 'X-Naver-Client-Secret': client_secret}

response = requests.post(url, files = files, headers = headers)

# %%
import json   # json형식을 다루는 모듈

parsed = json.loads(response.text)
print(json.dumps(parsed, indent = 4, sort_keys=False, ensure_ascii=False))
# Out:
# {
#     "info": {
#         "size": {
#             "width": 293,
#             "height": 172
#         },
#         "faceCount": 1
#     },
#     "faces": [
#         {
#             "roi": {
#                 "x": 116,
#                 "y": 41,
#                 "width": 47,
#                 "height": 47
#             },
#             "landmark": {
#                 "leftEye": {
#                     "x": 128,
#                     "y": 53
#                 },
#                 "rightEye": {
#                     "x": 151,
#                     "y": 54
#                 },
#                 "nose": {
#                     "x": 138,
#                     "y": 67
#                 },
#                 "leftMouth": {
#                     "x": 128,
#                     "y": 78
#                 },
#                 "rightMouth": {
#                     "x": 147,
#                     "y": 80
#                 }
#             },
#             "gender": {
#                 "value": "male",
#                 "confidence": 0.999987
#             },
#             "age": {
#                 "value": "28~32",
#                 "confidence": 0.863172
#             },
#             "emotion": {
#                 "value": "neutral",
#                 "confidence": 1.0
#             },
#             "pose": {
#                 "value": "frontal_face",
#                 "confidence": 0.997373
#             }
#         }
#     ]
# }

# %%
parsed.keys()
# Out:
# dict_keys(['info', 'faces'])

# %%
parsed['faces'][0]
# Out:
# {'roi': {'x': 116, 'y': 41, 'width': 47, 'height': 47},
#  'landmark': {'leftEye': {'x': 128, 'y': 53},
#   'rightEye': {'x': 151, 'y': 54},
#   'nose': {'x': 138, 'y': 67},
#   'leftMouth': {'x': 128, 'y': 78},
#   'rightMouth': {'x': 147, 'y': 80}},
#  'gender': {'value': 'male', 'confidence': 0.999987},
#  'age': {'value': '28~32', 'confidence': 0.863172},
#  'emotion': {'value': 'neutral', 'confidence': 1.0},
#  'pose': {'value': 'frontal_face', 'confidence': 0.997373}}

# %%
parsed['faces'][0]['roi']
#얼굴의 위치값
# Out:
# {'x': 116, 'y': 41, 'width': 47, 'height': 47}

# %%
parsed['faces'][0]['gender']
# Out:
# {'value': 'male', 'confidence': 0.999987}

# %%
parsed['faces'][0]['age']
# Out:
# {'value': '28~32', 'confidence': 0.863172}

# %%
parsed['faces'][0]['emotion']
# Out:
# {'value': 'neutral', 'confidence': 1.0}

# %%
x,y,w,h = parsed['faces'][0]['roi'].values()
gender,gen_confi = parsed['faces'][0]['gender'].values()
emotion,emo_confi = parsed['faces'][0]['emotion'].values()
age,age_confi = parsed['faces'][0]['age'].values()

# %%
annotation = gender + " : " + str(gen_confi) + '\n' + emotion + " : " + str(emo_confi) +'\n' + age + " ; " + str(age_confi)

# %%
print(annotation)
# Out:
# male : 0.999987
# neutral : 1.0
# 28~32 ; 0.863172

# %%
import matplotlib.patches as patches

img = mpimg.imread('face1.jfif')

fig, ax = plt.subplots(figsize = (10,10))
ax.imshow(img)

rect_face = patches.Rectangle((x,y),w,h,
                             linewidth = 5,
                             edgecolor = 'r',
                             facecolor = 'none')
ax.add_patch(rect_face)

plt.text(10,50, annotation, wrap=True, fontsize = 17, color ='white')
plt.show()

# %%
img = mpimg.imread('face2.jpg')

plt.figure(figsize=(10,8))
plt.imshow(img)
plt.show()

# %%
import requests  # 인터넷 연결

client_id = "JtzyEv6hdzG2mhfewvFn"
client_secret = "b7VOpgnzec"

url = "https://openapi.naver.com/v1/vision/face"
files = {'image':open('face2.jpg','rb')}
headers = {'X-Naver-Client-Id':client_id, 'X-Naver-Client-Secret': client_secret}

response = requests.post(url, files = files, headers = headers)

# %%
parsed = json.loads(response.text)
print(json.dumps(parsed, indent = 4, sort_keys=False, ensure_ascii=False))
# Out:
# {
#     "info": {
#         "size": {
#             "width": 512,
#             "height": 342
#         },
#         "faceCount": 4
#     },
#     "faces": [
#         {
#             "roi": {
#                 "x": 322,
#                 "y": 53,
#                 "width": 30,
#                 "height": 30
#             },
#             "landmark": {
#                 "leftEye": {
#                     "x": 331,
#                     "y": 60
#                 },
#                 "rightEye": {
#                     "x": 344,
#                     "y": 60
#                 },
#                 "nose": {
#                     "x": 337,
#                     "y": 67
#                 },
#                 "leftMouth": {
#                     "x": 333,
#                     "y": 74
#                 },
#                 "rightMouth": {
#                     "x": 343,
#                     "y": 73
#                 }
#             },
#             "gender": {
#                 "value": "male",
#                 "confidence": 0.999797
#             },
#             "age": {
#                 "value": "32~36",
#                 "confidence": 0.870835
#             },
#             "emotion": {
#                 "value": "neutral",
#                 "confidence": 0.941112
#             },
#             "pose": {
#                 "value": "frontal_face",
#                 "confidence": 0.990651
#             }
#         },
#         {
#             "roi": {
#                 "x": 268,
#                 "y": 71,
#                 "width": 28,
#                 "height": 28
#             },
#             "landmark": null,
#             "gender": {
#                 "value": "female",
#                 "confidence": 0.999965
#             },
#             "age": {
#                 "value": "18~22",
#                 "confidence": 0.870391
#             },
#             "emotion": {
#                 "value": "neutral",
#                 "confidence": 0.996715
#             },
#             "pose": {
#                 "value": "part_face",
#                 "confidence": 0.777422
#             }
#         },
#         {
#             "roi": {
#                 "x": 173,
#                 "y": 144,
#                 "width": 26,
#                 "height": 26
#             },
#             "landmark": null,
#             "gender": {
#                 "value": "male",
#                 "confidence": 0.882768
#             },
#             "age": {
#                 "value": "5~9",
#                 "confidence": 0.941211
#             },
#             "emotion": {
#                 "value": "smile",
#                 "confidence": 0.989725
#             },
#             "pose": {
#                 "value": "false_face",
#                 "confidence": 0.895872
#             }
#         },
#         {
#             "roi": {
#                 "x": 131,
#                 "y": 153,
#                 "width": 24,
#                 "height": 24
#             },
#             "landmark": {
#                 "leftEye": {
#                     "x": 138,
#                     "y": 159
#                 },
#                 "rightEye": {
#                     "x": 148,
#                     "y": 159
#                 },
#                 "nose": {
#                     "x": 143,
#                     "y": 164
#                 },
#                 "leftMouth": {
#                     "x": 139,
#                     "y": 168
#                 },
#                 "rightMouth": {
#                     "x": 147,
#                     "y": 168
#                 }
#             },
#             "gender": {
#                 "value": "female",
#                 "confidence": 0.902951
#             },
#             "age": {
#                 "value": "9~13",
#                 "confidence": 0.0996041
#             },
#             "emotion": {
#                 "value": "neutral",
#                 "confidence": 0.897915
#             },
#             "pose": {
#                 "value": "frontal_face",
#                 "confidence": 0.96725
#             }
#         }
#     ]
# }

# %%
import matplotlib.patches as patches

img = mpimg.imread('face2.jpg')

fig, ax = plt.subplots(figsize = (10,10))
ax.imshow(img)



for each in parsed['faces']:
    
    
    x,y,w,h = each['roi'].values()
    gender,gen_confi = each['gender'].values()
    emotion,emo_confi = each['emotion'].values()
    age,age_confi = each['age'].values()
    
    rect_face = patches.Rectangle((x,y),w,h,
                                 linewidth = 5,
                                 edgecolor = 'r',
                                 facecolor = 'none')
    ax.add_patch(rect_face)   
    annotation =  gender + " : " + str(round(gen_confi*100,2))+'%' + '\n' + emotion + " : " + str(round(emo_confi*100,2))+'%' +'\n' + age + " ; " + str(round(age_confi*100,2))+'%'

    plt.text(x-15,y-20, annotation, wrap=True, fontsize = 7, color = 'black')

    
    
    
plt.show()
